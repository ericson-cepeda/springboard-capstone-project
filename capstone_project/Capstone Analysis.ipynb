# %%
import pandas as pd
df = pd.read_csv('train.tsv', sep='\t', index_col='train_id')
df = df[df['category_name'] == 'Electronics/Video Games & Consoles/Games']
df.head()
# Out:
#                                       name  \
# train_id
# 91           Goosebumps HorrorLand DS Game
# 177              NBA 2k14 BRAND NEW SEALED
# 233       Rockstar Bundle (Xbox 360 / One)
# 237        Lego Harry Potter Years 1-4 Wii
# 276                            Nintendo 64
#
#                                            item_description
# train_id
# 91         Good used condition. Ask about bundling to save.
# 177       I am a first time seller located in California...
# 233       Brand New! Factory Sealed! Fast & Free Shippin...
# 237       Lego Harry Potter Years 1-4 Wii E10+ Warner Br...
# 276       Here I have a Nintendo 64 old school Everythin...
#                                       name  item_condition_id  \
# train_id
# 91           Goosebumps HorrorLand DS Game                  3
# 177              NBA 2k14 BRAND NEW SEALED                  1
# 233       Rockstar Bundle (Xbox 360 / One)                  1
# 237        Lego Harry Potter Years 1-4 Wii                  2
# 276                            Nintendo 64                  3
#
#                                      category_name brand_name  price  \
# train_id
# 91        Electronics/Video Games & Consoles/Games   Nintendo   10.0
# 177       Electronics/Video Games & Consoles/Games       Sony    6.0
# 233       Electronics/Video Games & Consoles/Games       Xbox   38.0
# 237       Electronics/Video Games & Consoles/Games   Nintendo   19.0
# 276       Electronics/Video Games & Consoles/Games   Nintendo  124.0
#
#           shipping                                   item_description
# train_id
# 91               0   Good used condition. Ask about bundling to save.
# 177              1  I am a first time seller located in California...
# 233              1  Brand New! Factory Sealed! Fast & Free Shippin...
# 237              0  Lego Harry Potter Years 1-4 Wii E10+ Warner Br...
# 276              0  Here I have a Nintendo 64 old school Everythin...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26557 entries, 91 to 1482507
# Data columns (total 7 columns):
# name                 26557 non-null object
# item_condition_id    26557 non-null int64
# category_name        26557 non-null object
# brand_name           19851 non-null object
# price                26557 non-null float64
# shipping             26557 non-null int64
# item_description     26557 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#        item_condition_id         price      shipping
# count       26557.000000  26557.000000  26557.000000
# mean            2.519336     24.119667      0.530143
# std             0.770935     29.139653      0.499100
# min             1.000000      0.000000      0.000000
# 25%             2.000000     10.000000      0.000000
# 50%             3.000000     16.000000      1.000000
# 75%             3.000000     28.000000      1.000000
# max             5.000000   1254.000000      1.000000

# %%
df.columns.value_counts()
# Out:
# name                 1
# price                1
# item_condition_id    1
# category_name        1
# item_description     1
# shipping             1
# brand_name           1
# dtype: int64

# %%
import sklearn
df[['name', 'item_description']].to_csv('electronics.csv', index=False)
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(input='electronics.csv')
item_description_matrix = vectorizer.fit_transform(df.item_description.values)
item_description_matrix
# Out:
# <26557x11656 sparse matrix of type '<class 'numpy.float64'>'
# 	with 410444 stored elements in Compressed Sparse Row format>

# %%
vectorizer.vocabulary_
# Out:
# {'good': 4553,
#  'used': 10930,
#  'condition': 2437,
#  'ask': 1009,
#  'about': 543,
#  'bundling': 1789,
#  'to': 10465,
#  'save': 8966,
#  'am': 800,
#  'first': 4052,
#  'time': 10434,
#  'seller': 9107,
#  'located': 6066,
#  'in': 5222,
#  'california': 1859,
#  'usa': 10923,
#  'highly': 4953,
#  'appreciate': 924,
#  'if': 5158,
#  'able': 542,
#  'sell': 9106,
#  'his': 4971,
#  'the': 10315,
#  'us': 10922,
#  'this': 10359,
#  'game': 4338,
#  'has': 4821,
#  'not': 7072,
#  'been': 1353,
#  'brand': 1666,
#  'new': 6948,
#  'sealed': 9059,
#  'for': 4150,
#  'ps4': 8092,
#  'factory': 3848,
#  'fast': 3900,
#  'free': 4218,
#  'shipping': 9251,
#  'price': 7978,
#  'is': 5417,
#  'firm': 4049,
#  'please': 7783,
#  'don': 3246,
#  'includes': 5237,
#  'grand': 4594,
#  'theft': 10320,
#  'auto': 1101,
#  'iv': 5446,
#  'complete': 2406,
#  'edition': 3468,
#  'red': 8409,
#  'dead': 2866,
#  'redemption': 8416,
#  'goty': 4572,
#  'lego': 5911,
#  'harry': 4816,
#  'potter': 7907,
#  'years': 11562,
#  'wii': 11312,
#  'e10': 3416,
#  'warner': 11178,
#  'bros': 1717,
#  'games': 4357,
#  '2010': 163,
#  'here': 4933,
#  'have': 4842,
#  'nintendo': 7019,
#  '64': 417,
#  'old': 7210,
#  'school': 9003,
#  'everything': 3708,
#  'works': 11418,
#  'comes': 2350,
#  'with': 11371,
#  'cords': 2551,
#  'remotes': 8516,
#  'memory': 6454,
#  'blocks': 1518,
#  'would': 11437,
#  'love': 6126,
#  'someone': 9563,
#  'rekindle': 8477,
#  'their': 10321,
#  'childhood': 2123,
#  'memories': 6453,
#  'ran': 8256,
#  'across': 594,
#  'other': 7335,
#  'people': 7577,
#  'on': 7225,
#  'mecari': 6411,
#  'selling': 9111,
#  'item': 5439,
#  'and': 839,
#  'best': 1403,
#  'bundle': 1786,
#  'no': 7039,
#  'description': 2998,
#  'yet': 11571,
#  'great': 4608,
#  'little': 6037,
#  'that': 10313,
#  'keeps': 5645,
#  'your': 11591,
#  'mind': 6559,
#  'sharp': 9207,
#  'lots': 6120,
#  'of': 7179,
#  'things': 10352,
#  'do': 3205,
#  'while': 11284,
#  'you': 11585,
#  'learn': 5885,
#  'spanish': 9619,
#  'it': 5433,
#  'instruction': 5341,
#  'book': 1589,
#  'also': 787,
#  'disc': 3128,
#  'shape': 9193,
#  'tracking': 10569,
#  'weighs': 11252,
#  'oz': 7396,
#  'so': 9529,
#  'fable': 3833,
#  'xbox360': 11509,
#  'more': 6698,
#  'checkout': 2098,
#  'my': 6804,
#  'closet': 2261,
#  'excellent': 3734,
#  'overall': 7366,
#  'metal': 6491,
#  'gear': 4404,
#  'solid': 9550,
#  'phantom': 7637,
#  'pain': 7423,
#  'xbox': 11507,
#  'one': 7229,
#  'minor': 6582,
#  'play': 7757,
#  'scratches': 9022,
#  'played': 7762,
#  'thanks': 10311,
#  'missing': 6608,
#  'booklet': 1591,
#  'boktai': 1568,
#  'box': 1645,
#  'gba': 4398,
#  'painted': 7426,
#  'over': 7365,
#  '10': 27,
#  'watch': 11202,
#  'battery': 1281,
#  'does': 3219,
#  'conflict': 2456,
#  'saves': 8969,
#  'only': 7236,
#  'now': 7090,
#  'through': 10391,
#  'christmas': 2159,
#  'buy': 1828,
#  'rm': 8753,
#  'items': 5440,
#  'get': 4449,
#  'message': 6483,
#  'me': 6401,
#  'create': 2647,
#  'listing': 6023,
#  'almost': 774,
#  'perfect': 7589,
#  'copy': 2546,
#  'dragon': 3299,
#  'age': 689,
#  'inquisition': 5312,
#  'very': 11009,
#  'competitive': 2400,
#  'pricing': 7983,
#  'both': 1620,
#  '100': 28,
#  'tested': 10292,
#  'all': 760,
#  'original': 7313,
#  'books': 1596,
#  'cd': 2006,
#  'included': 5235,
#  'once': 7226,
#  'practically': 7924,
#  'castlevania': 1980,
#  'lords': 6109,
#  'shadow': 9183,
#  'mirror': 6596,
#  'fate': 3906,
#  'track': 10566,
#  'package': 7403,
#  'we': 11225,
#  'usually': 10938,
#  'ship': 9244,
#  'within': 11373,
#  'days': 2853,
#  'purchase': 8126,
#  'will': 11329,
#  'receive': 8369,
#  'as': 995,
#  'soon': 9578,
#  'available': 1116,
#  'are': 952,
#  'listed': 6019,
#  'just': 5587,
#  'let': 5931,
#  'know': 5734,
#  'what': 11269,
#  'want': 11152,
#  'bigger': 1432,
#  'discount': 3138,
#  'can': 1876,
#  'give': 4489,
#  'together': 10480,
#  'check': 2093,
#  'out': 7342,
#  'our': 7341,
#  'cool': 2535,
#  'carry': 1943,
#  '360': 292,
#  'playstation': 7773,
#  'gamecube': 4343,
#  'gameboy': 4340,
#  'nes': 6935,
#  'snes': 9516,
#  'n64': 6825,
#  'sega': 9096,
#  'mario': 6305,
#  'super': 10019,
#  'smash': 9478,
#  '3ds': 308,
#  'sets': 9158,
#  'shows': 9294,
#  'signs': 9327,
#  'wear': 11231,
#  'these': 10336,
#  'older': 7211,
#  'but': 1816,
#  'tons': 10505,
#  'battleship': 1297,
#  'disney': 3154,
#  'cars': 1945,
#  'sticker': 9861,
#  'peel': 7554,
#  'off': 7180,
#  'speed': 9657,
#  'machines': 6187,
#  'pipe': 7709,
#  'mama': 6256,
#  'brain': 1663,
#  'age2': 690,
#  'backyard': 1175,
#  'sports': 9712,
#  'sandlot': 8942,
#  'sluggers': 9465,
#  'hannah': 4781,
#  'montana': 6687,
#  'sonic': 9573,
#  'olympic': 7218,
#  'winter': 11350,
#  'woshi': 11433,
#  'katsuma': 5632,
#  'unleashed': 10848,
#  'donkey': 3251,
#  'kong': 5753,
#  'country': 2601,
#  'tropical': 10665,
#  'freeze': 4230,
#  'like': 5978,
#  'any': 892,
#  'or': 7285,
#  'cartridge': 1957,
#  'before': 1355,
#  'buying': 1831,
#  'make': 6244,
#  'sure': 10056,
#  'still': 9869,
#  'up': 10895,
#  'because': 1345,
#  'ebay': 3448,
#  'may': 6381,
#  'be': 1313,
#  'anymore': 895,
#  'international': 5383,
#  'include': 5234,
#  'carnival': 1933,
#  'animal': 860,
#  'kingdom': 5695,
#  'wildlifw': 11326,
#  'expedition': 3775,
#  'wipeout': 11354,
#  'dance': 2801,
#  'pretty': 7970,
#  'much': 6757,
#  'bucks': 1748,
#  'questions': 8183,
#  'pink': 7703,
#  'camo': 1870,
#  'limited': 5994,
#  'remote': 8515,
#  'sale': 8920,
#  'nunchuk': 7111,
#  'working': 11415,
#  'never': 6945,
#  'opened': 7254,
#  'nhl': 6964,
#  '16': 87,
#  'video': 11036,
#  'consoles': 2492,
#  'accessories': 568,
#  'store': 9891,
#  'color': 2327,
#  'coded': 2291,
#  'search': 9063,
#  'condtion': 2445,
#  'island': 5420,
#  'pc': 7533,
#  'dvd': 3404,
#  'rom': 8802,
#  'software': 9541,
#  'mature': 6372,
#  '17': 97,
#  'plays': 7768,
#  'alienware': 753,
#  'nvidia': 7119,
#  '3d': 303,
#  'vision': 11079,
#  'ready': 8335,
#  'system': 10125,
#  'requirements': 8576,
#  'windows': 11339,
#  'xp': 11536,
#  'vista': 11083,
#  'sp1': 9609,
#  'gb': 4397,
#  'perfectly': 7591,
#  'fine': 4024,
#  'gone': 4548,
#  'psp': 8097,
#  'case': 1963,
#  '12': 56,
#  'movies': 6741,
#  'burnout': 1798,
#  'daxter': 2851,
#  'nba': 6877,
#  '06': 18,
#  'ballout': 1199,
#  'rebound': 8361,
#  'tomb': 10490,
#  'raider': 8231,
#  'anniversary': 872,
#  'movie': 6740,
#  'goblet': 4528,
#  'fire': 4039,
#  'sky': 9412,
#  'high': 4948,
#  'vice': 11030,
#  'city': 2195,
#  'stories': 9894,
#  'hot': 5063,
#  'shots': 9280,
#  'golf': 4547,
#  'ssx': 9756,
#  'tour': 10547,
#  'feantix': 3924,
#  'charger': 2071,
#  'which': 11282,
#  'why': 11299,
#  'doesn': 3220,
#  'cost': 2581,
#  'small': 9472,
#  'defect': 2925,
#  'screen': 9029,
#  'post': 7897,
#  'pics': 7674,
#  'later': 5845,
#  'after': 680,
#  'charged': 2070,
#  'whitney': 11291,
#  'margie': 6301,
#  'dsi': 3362,
#  'ds': 3359,
#  'come': 2348,
#  'stylus': 9970,
#  'feel': 3944,
#  'tags': 10146,
#  'kart': 5623,
#  'work': 11409,
#  'shipped': 9249,
#  'manual': 6284,
#  'carts': 1960,
#  'mint': 6585,
#  'boxes': 1649,
#  'manuals': 6287,
#  'pictured': 7677,
#  'authentic': 1097,
#  'without': 11375,
#  'issue': 5430,
#  'hours': 5070,
#  'endless': 3577,
#  'dk': 3190,
#  'gaming': 4366,
#  'fun': 4277,
#  'nice': 6973,
#  'holder': 4997,
#  '2ds': 223,
#  'systems': 10127,
#  'ships': 9253,
#  'next': 6958,
#  'day': 2852,
#  'miniland': 6572,
#  'mayhem': 6385,
#  'diddykong': 3073,
#  'racing': 8215,
#  'jungle': 5580,
#  'climber': 2244,
#  'page': 7419,
#  'ps1': 8086,
#  'ps2': 8087,
#  'ps3': 8089,
#  'easy': 3443,
#  'find': 4020,
#  'organized': 7304,
#  'into': 5388,
#  'own': 7389,
#  'section': 9077,
#  'back': 1159,
#  'weekly': 11246,
#  'sales': 8922,
#  'deals': 2876,
#  'money': 6673,
#  'otherwise': 7337,
#  'prices': 7981,
#  'due': 3376,
#  'fees': 3947,
#  'were': 11263,
#  'raised': 8242,
#  'applied': 922,
#  'same': 8928,
#  'pen': 7568,
#  'nor': 7059,
#  'separate': 9128,
#  'open': 7252,
#  'offers': 7187,
#  'multiple': 6765,
#  'combine': 2342,
#  'genuine': 4441,
#  '24': 191,
#  'wolfenstein': 11384,
#  'order': 7294,
#  'discs': 3144,
#  'function': 4279,
#  'should': 9282,
#  'show': 9286,
#  'from': 4254,
#  'use': 10928,
#  'comment': 2369,
#  'below': 1378,
#  'kémon': 5780,
#  'emerald': 3532,
#  'version': 11003,
#  'advance': 650,
#  'pokémon': 7837,
#  'flaw': 4088,
#  'name': 6839,
#  'written': 11475,
#  'borderlands': 1611,
#  'handsome': 4773,
#  'collection': 2316,
#  'few': 3964,
#  'times': 10439,
#  'banjo': 1217,
#  'kazooie': 5638,
#  'marker': 6317,
#  'front': 4257,
#  'top': 10519,
#  'see': 9085,
#  'purchased': 8127,
#  'by': 1837,
#  'accident': 570,
#  'kids': 5675,
#  'gave': 4395,
#  'nintendogs': 7022,
#  'clean': 2227,
#  'label': 5787,
#  'bioshock': 1457,
#  'adult': 647,
#  'owned': 7390,
#  'well': 11260,
#  'taken': 10153,
#  'care': 1919,
#  'always': 798,
#  'offer': 7184,
#  'add': 619,
#  'profile': 8037,
#  'needs': 6909,
#  'taking': 10157,
#  'look': 6098,
#  'mon': 6669,
#  'fri': 4237,
#  'isn': 5424,
#  'weekends': 11245,
#  'understanding': 10814,
#  'msg': 6753,
#  'ac': 555,
#  'adapter': 615,
#  'zero': 11626,
#  'many': 6293,
#  'they': 10339,
#  'affect': 670,
#  'gameplay': 4353,
#  'there': 10331,
#  'noticeable': 7079,
#  'however': 5083,
#  'several': 9167,
#  'worked': 11411,
#  'last': 5838,
#  'was': 11192,
#  'upon': 10909,
#  'request': 8570,
#  'final': 4015,
#  'fantasy': 3884,
#  'based': 1248,
#  'weight': 11253,
#  'crash': 2634,
#  'bandicoot': 1209,
#  'warped': 11181,
#  'had': 4732,
#  'really': 8345,
#  'vintage': 11062,
#  'saved': 8967,
#  'world': 11420,
#  'being': 1368,
#  'erased': 3648,
#  'an': 831,
#  'evil': 3714,
#  'person': 7610,
#  'need': 6905,
#  'hero': 4934,
#  'travel': 10617,
#  'fight': 3991,
#  'monsters': 6686,
#  'regain': 8455,
#  'worlds': 11421,
#  'battletoads': 1299,
#  'battlemaniacs': 1293,
#  'wayne': 11219,
#  'tinstar': 10444,
#  'judge': 5564,
#  'dredd': 3326,
#  'toys': 10562,
#  'cleaning': 2231,
#  'attic': 1080,
#  'found': 4189,
#  'ton': 10499,
#  'instead': 5336,
#  'letting': 5936,
#  'them': 10323,
#  'lay': 5859,
#  'around': 980,
#  'collect': 2309,
#  'dust': 3398,
#  'go': 4523,
#  'keep': 5642,
#  'stains': 9774,
#  'covers': 2618,
#  'idea': 5149,
#  'when': 11278,
#  'kid': 5672,
#  'via': 11022,
#  'usps': 10936,
#  'business': 1806,
#  'cleared': 2236,
#  'payment': 7529,
#  'information': 5284,
#  'provided': 8081,
#  'contact': 2498,
#  'concerns': 2430,
#  'thank': 10310,
#  'visit': 11080,
#  'controller': 2521,
#  'barely': 1227,
#  'grinch': 4631,
#  'faded': 3850,
#  'unsure': 10884,
#  'alcohol': 738,
#  'rub': 8848,
#  'until': 10887,
#  'dawn': 2849,
#  'sony': 9576,
#  'horror': 5055,
#  'retails': 8638,
#  'tax': 10210,
#  'stores': 9893,
#  'makes': 6248,
#  'present': 7955,
#  'gift': 4471,
#  'wrap': 11445,
#  'part': 7477,
#  'promo': 8050,
#  'legacy': 5900,
#  'classic': 2216,
#  'monster': 6684,
#  'house': 5071,
#  'happy': 4788,
#  'feet': 3948,
#  'kirby': 5703,
#  'air': 718,
#  'ride': 8705,
#  'fallout': 3868,
#  'dragonball': 3300,
#  'xenoverse': 11519,
#  'ps': 8085,
#  'vita': 11087,
#  'card': 1915,
#  'fossil': 4184,
#  'fighters': 3993,
#  'battle': 1285,
#  'giants': 4468,
#  'dragons': 3307,
#  'long': 6094,
#  'mega': 6429,
#  'cover': 2614,
#  'piece': 7682,
#  'adventure': 655,
#  'tiger': 10422,
#  'woods': 11402,
#  'pga': 7631,
#  'muppets': 6774,
#  'party': 7489,
#  'cruise': 2695,
#  'call': 1860,
#  'duty': 3403,
#  'finest': 4026,
#  'hour': 5068,
#  'lord': 6108,
#  'rings': 8726,
#  'two': 10738,
#  'towers': 10552,
#  'legend': 5902,
#  'zelda': 11620,
#  'four': 4191,
#  'swords': 10106,
#  'adventures': 656,
#  'ice': 5142,
#  'meltdown': 6444,
#  'chamber': 2040,
#  'secrets': 9076,
#  'mvp': 6794,
#  'baseball': 1247,
#  '2005': 157,
#  'resident': 8597,
#  'umbrella': 10778,
#  'chronicles': 2164,
#  'galaxy': 4333,
#  'rated': 8288,
#  'slight': 9447,
#  'language': 5822,
#  'blood': 1520,
#  'gore': 4564,
#  'violence': 11065,
#  'zombies': 11641,
#  'related': 8479,
#  'cod': 2287,
#  'cartoon': 1954,
#  'lotr': 6119,
#  'rest': 8620,
#  'bought': 1632,
#  'separately': 9131,
#  'highest': 4950,
#  'plus': 7797,
#  'single': 9359,
#  'disks': 3153,
#  'scratched': 9020,
#  'nothing': 7077,
#  'bad': 1176,
#  'enough': 3606,
#  'effect': 3479,
#  'xl': 11527,
#  'pacman': 7412,
#  'brothers': 1721,
#  'light': 5962,
#  'sing': 9357,
#  'pop': 7863,
#  'hits': 4978,
#  'microphone': 6527,
#  'securely': 9081,
#  'listings': 6024,
#  'xiv': 11526,
#  'realm': 8346,
#  'reborn': 8360,
#  'heavensward': 4891,
#  'sons': 9575,
#  'liberty': 5946,
#  'mgs': 6511,
#  'snake': 9507,
#  'eater': 3445,
#  'harvest': 4819,
#  'moon': 6692,
#  'edit': 3466,
#  'went': 11262,
#  'added': 621,
#  'sun': 10006,
#  'flaws': 4091,
#  'awesome': 1136,
#  'print': 7995,
#  'weeks': 11248,
#  'ago': 699,
#  'cosmetic': 2574,
#  'gears': 4407,
#  'war': 11158,
#  'shopping': 9271,
#  'import': 5207,
#  'gameboys': 4342,
#  'looking': 6100,
#  'mas': 6339,
#  'presents': 7958,
#  'budget': 1752,
#  'copies': 2544,
#  'luigi': 6156,
#  'paper': 7457,
#  'jam': 5471,
#  'boom': 1597,
#  'shattered': 9210,
#  'crystal': 2706,
#  'land': 5816,
#  'cleaned': 2228,
#  'bubble': 1742,
#  'site': 9371,
#  'charge': 2069,
#  'fee': 3938,
#  'mafia': 6204,
#  'iii': 5168,
#  'son': 9568,
#  'maybe': 6383,
#  '3x': 328,
#  'yr': 11601,
#  'scratch': 9019,
#  'warranty': 11184,
#  'workin': 11414,
#  'lost': 6116,
#  'gain': 4326,
#  'family': 3876,
#  'received': 8370,
#  'him': 4962,
#  'army': 977,
#  'stationed': 9826,
#  'germany': 4448,
#  'spine': 9682,
#  'art': 990,
#  'yoshi': 11581,
#  'dry': 3358,
#  'means': 6406,
#  'progress': 8042,
#  'events': 3696,
#  'such': 9983,
#  'berries': 1396,
#  'regrow': 8465,
#  'trees': 10630,
#  'elgato': 3510,
#  'hd': 4861,
#  '60': 410,
#  'capture': 1910,
#  'chords': 2152,
#  'mariokart': 6308,
#  'ufc': 10762,
#  'pre': 7928,
#  'dark': 2818,
#  'level': 5937,
#  'trap': 10611,
#  'team': 10227,
#  'blue': 1534,
#  'useable': 10929,
#  'spy': 9727,
#  'something': 9564,
#  'eye': 3825,
#  'whole': 11295,
#  'enjoy': 3599,
#  'going': 4539,
#  'each': 3418,
#  'searching': 9064,
#  'hidden': 4944,
#  'objects': 7140,
#  'stage': 9768,
#  'levels': 5938,
#  'answers': 880,
#  'riddles': 8704,
#  'bring': 1704,
#  'machine': 6186,
#  'life': 5957,
#  'forget': 4163,
#  'cart': 1946,
#  'midnight': 6535,
#  'club': 2269,
#  'smackdown': 9471,
#  'vs': 11118,
#  'raw': 8301,
#  'mlb': 6626,
#  '08': 21,
#  'mile': 6546,
#  'read': 8329,
#  'repost': 8555,
#  'rampage': 8253,
#  'pokemon': 7824,
#  'xd': 11514,
#  'll': 6050,
#  'cases': 1966,
#  'too': 10510,
#  'clip': 2248,
#  'bottom': 1628,
#  'remastered': 8503,
#  'fan': 3878,
#  'ff': 3965,
#  'series': 9147,
#  'hello': 4914,
#  'exact': 3727,
#  'reserved': 8589,
#  'az': 1145,
#  'gamer': 4355,
#  'prop': 8057,
#  'energy': 3584,
#  'sword': 10103,
#  'lights': 5971,
#  'noise': 7047,
#  'negotiate': 6914,
#  'reasonable': 8353,
#  'rarely': 8278,
#  'dropped': 3349,
#  'runs': 8877,
#  'smoothly': 9500,
#  'error': 3656,
#  'messages': 6484,
#  'green': 4615,
#  'yellow': 11564,
#  'colors': 2331,
#  'yellows': 11567,
#  'ruby': 8856,
#  'run': 8873,
#  'sold': 9544,
#  'console': 2491,
#  'special': 9639,
#  'skylander': 9414,
#  'imaginations': 5185,
#  'jingle': 5521,
#  'bell': 1371,
#  'chompy': 2145,
#  'mage': 6212,
#  'packaging': 7406,
#  'above': 544,
#  'customer': 2743,
#  'wrapping': 11449,
#  'guarantee': 4669,
#  'tom': 10488,
#  'clancy': 2207,
#  'rainbow': 8236,
#  'six': 9378,
#  'jumping': 5575,
#  'flash': 4081,
#  'bobble': 1561,
#  'bonanza': 1575,
#  'station': 9825,
#  'urban': 10918,
#  'chaos': 2058,
#  'right': 8716,
#  'response': 8616,
#  'bundles': 1788,
#  'welcomed': 11258,
#  'advanced': 651,
#  'some': 9559,
#  'natural': 6867,
#  'holds': 5000,
#  'japanese': 5480,
#  'every': 3704,
#  'psvita': 8100,
#  'region': 8459,
#  'locked': 6072,
#  'miss': 6604,
#  'amazing': 804,
#  'yes': 11569,
#  'negotiable': 6913,
#  'everyday': 3706,
#  '2k16': 237,
#  'bachelorette': 1158,
#  'activity': 606,
#  'cards': 1918,
#  'sexy': 9174,
#  'passionate': 7495,
#  'gifts': 4473,
#  'friends': 4244,
#  'kindle': 5688,
#  'fireplace': 4041,
#  'skyrim': 9416,
#  'gta5': 4664,
#  'earthworm': 3437,
#  'jim': 5519,
#  'fair': 3857,
#  'pictures': 7678,
#  'details': 3031,
#  'class': 2214,
#  'seal': 9057,
#  'tooken': 10513,
#  'nore': 7060,
#  'parker': 7475,
#  'electronic': 3504,
#  'talking': 10163,
#  'clue': 2273,
#  'fx': 4314,
#  'bonus': 1584,
#  '36': 291,
#  'titles': 10457,
#  'less': 5927,
#  'than': 10309,
#  'per': 7581,
#  'hope': 5041,
#  'set': 9157,
#  'viewing': 11045,
#  'additional': 627,
#  'interest': 5372,
#  'those': 10366,
#  'shown': 9293,
#  'put': 8146,
#  'deal': 2872,
#  'say': 8975,
#  'low': 6133,
#  'grab': 4580,
#  'its': 5444,
#  'steel': 9840,
#  'longer': 6096,
#  'serious': 9148,
#  'buyers': 1830,
#  'tony': 10507,
#  'hawk': 4851,
#  'pro': 8013,
#  'skater': 9390,
#  'black': 1474,
#  'cannot': 1889,
#  'guarantees': 4671,
#  'smoke': 9493,
#  'pet': 7621,
#  'contains': 2505,
#  'prey': 7977,
#  'cosmonaut': 2578,
#  'shotgun': 9279,
#  'pack': 7402,
#  'justice': 5589,
#  'leagues': 5878,
#  'second': 9071,
#  'installment': 5331,
#  'injustice': 5293,
#  'interested': 5373,
#  'immediate': 5193,
#  'receipt': 8368,
#  'gently': 4440,
#  'platform': 7750,
#  'toadstool': 10470,
#  'dave': 2845,
#  'mira': 6592,
#  'freestyle': 4229,
#  'bmx': 1542,
#  'kelly': 5648,
#  'slater': 9428,
#  'surfer': 10060,
#  'ncaa': 6886,
#  '2k3': 239,
#  'football': 4146,
#  'unfortunately': 10825,
#  'protective': 8070,
#  'sleeve': 9436,
#  'decide': 2899,
#  'respond': 8614,
#  'another': 877,
#  'rpg': 8845,
#  'three': 10378,
#  'cracks': 2627,
#  'else': 3518,
#  'pins': 7707,
#  'karate': 5619,
#  'champ': 2042,
#  'town': 10554,
#  'surf': 10057,
#  'designs': 3006,
#  'turbo': 10700,
#  '11': 48,
#  'device': 3048,
#  'matching': 6356,
#  'earbuds': 3423,
#  'yellowing': 11566,
#  'refer': 8433,
#  'afraid': 677,
#  'willing': 11331,
#  'generally': 4419,
#  'vary': 10978,
#  'shooter': 9265,
#  'anything': 897,
#  'unclear': 10800,
#  'csi': 2712,
#  ...}

# %%
df.item_description.values
# Out:
# array(['Good used condition. Ask about bundling to save.',
#        'I am a first time seller located in California USA I highly appreciate if I am able to sell his in the US. This game has not been used brand new sealed for PS4',
#        "Brand New! Factory Sealed! Fast & Free Shipping! Price is firm please don't ask! Includes: • Grand Theft Auto IV Complete Edition • Red Dead Redemption GOTY Edition",
#        ...,
#        'GAME IS BRAND NEW FACTORY SEALED **YES IT IS AVAILABLE. NO NEED TO ASK** **PRICE NOT NEGOTIABLE** I SHIP EVERYDAY. FREE 2-DAY SHIPPING THANK YOU. HAVE A GREAT DAY',
#        '2 XBOX games Call of duty and Halo',
#        'Just the game and the case. Lightly used.'], dtype=object)

# %%
vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000',
#  '0001',
#  '001',
#  '005',
#  '006',
#  '007',
#  '01',
#  '011',
#  '012',
#  '017',
#  '01v',
#  '02',
#  '03',
#  '04',
#  '047754139945',
#  '05',
#  '06',
#  '07',
#  '071207',
#  '08',
#  '087',
#  '089',
#  '09',
#  '0964',
#  '0v',
#  '10',
#  '100',
#  '1000',
#  '10000000000000',
#  '1000hz',
#  '1000ma',
#  '1001',
#  '1001a',
#  '100s',
#  '101',
#  '104',
#  '1040',
#  '1080',
#  '1080p',
#  '10adp',
#  '10cm',
#  '10g',
#  '10games',
#  '10lbs',
#  '10minutes',
#  '10th',
#  '11',
#  '110',
#  '1101',
#  '110v',
#  '111',
#  '112',
#  '11am',
#  '11th',
#  '12',
#  '120',
#  '1200',
#  '1200mah',
#  '122',
#  '123',
#  '1234',
#  '124mm',
#  '128',
#  '12836088',
#  '128mb',
#  '129',
#  '12games',
#  '13',
#  '130',
#  '1300xt',
#  '130g',
#  '132g',
#  '13oz',
#  '13th',
#  '14',
#  '140',
#  '143',
#  '146',
#  '149',
#  '14days',
#  '15',
#  '150',
#  '1500',
#  '1500mah',
#  '150in1',
#  '16',
#  '160',
#  '1600',
#  '1602',
#  '160gb',
#  '1631',
#  '167',
#  '1697',
#  '16gb',
#  '16oz',
#  '17',
#  '1715',
#  '175',
#  '1789',
#  '18',
#  '180',
#  '1800',
#  '1866mhz',
#  '1886',
#  '1886_',
#  '18m',
#  '18th',
#  '19',
#  '1940',
#  '1942',
#  '1968',
#  '1970s',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1985',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1and',
#  '1business',
#  '1car',
#  '1controller',
#  '1controlller',
#  '1e9n4',
#  '1game',
#  '1gb',
#  '1ms',
#  '1mth',
#  '1pk',
#  '1s',
#  '1st',
#  '1tb',
#  '1time',
#  '1vmu',
#  '1x',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200mm',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2020',
#  '2022',
#  '2025',
#  '2026',
#  '2033',
#  '20gb',
#  '20lbs',
#  '20th',
#  '21',
#  '210t',
#  '21lbs',
#  '21st',
#  '22',
#  '220',
#  '224',
#  '23',
#  '230',
#  '235',
#  '23k',
#  '24',
#  '2400',
#  '240v',
#  '249',
#  '24hours',
#  '24hr',
#  '24hrs',
#  '25',
#  '250',
#  '2500',
#  '2501a',
#  '250gb',
#  '251',
#  '2560',
#  '259',
#  '25th',
#  '26',
#  '260',
#  '2600',
#  '269',
#  '27',
#  '28',
#  '2800mah',
#  '29',
#  '290',
#  '298',
#  '29lbs',
#  '29th',
#  '2a',
#  '2casets',
#  '2controls',
#  '2d',
#  '2ds',
#  '2for',
#  '2games',
#  '2gb',
#  '2gta',
#  '2in',
#  '2k',
#  '2k1',
#  '2k10',
#  '2k11',
#  '2k12',
#  '2k13',
#  '2k14',
#  '2k15',
#  '2k16',
#  '2k17',
#  '2k3',
#  '2k4',
#  '2k5',
#  '2k6',
#  '2k7',
#  '2k8',
#  '2k9',
#  '2lb',
#  '2mm',
#  '2nd',
#  '2pack',
#  '2pm',
#  '2t',
#  '2tb',
#  '2wii',
#  '2x',
#  '2x1',
#  '2xl',
#  '2xmango',
#  '2xs',
#  '2xtreme',
#  '30',
#  '300',
#  '3000',
#  '30001',
#  '3000dpi',
#  '3000rpn',
#  '3001',
#  '300mm',
#  '307',
#  '30game',
#  '30th',
#  '30v',
#  '31',
#  '310',
#  '31st',
#  '32',
#  '320',
#  '3200',
#  '320gb',
#  '32g',
#  '32gb',
#  '32mb',
#  '32x',
#  '33',
#  '33745',
#  '34',
#  '345',
#  '34u',
#  '35',
#  '350',
#  '35mm',
#  '36',
#  '360',
#  '3600mah',
#  '369',
#  '36mm',
#  '36v',
#  '37',
#  '38',
#  '39',
#  '399',
#  '3_',
#  '3aaa',
#  '3d',
#  '3days',
#  '3dgame',
#  '3dl',
#  '3dland',
#  '3ds',
#  '3dsgames',
#  '3dsll',
#  '3dsxl',
#  '3ft',
#  '3games',
#  '3gently',
#  '3girls',
#  '3hour',
#  '3in',
#  '3lbs',
#  '3m',
#  '3months',
#  '3on3',
#  '3pcs',
#  '3pl',
#  '3pm',
#  '3po',
#  '3rd',
#  '3t',
#  '3x',
#  '3x1',
#  '40',
#  '400',
#  '404',
#  '40mm',
#  '40th',
#  '413',
#  '42',
#  '420',
#  '43',
#  '44',
#  '45',
#  '450',
#  '460',
#  '47',
#  '479',
#  '48',
#  '49',
#  '493',
#  '4_',
#  '4aa',
#  '4days',
#  '4e',
#  '4g',
#  '4gb',
#  '4ghz',
#  '4gig',
#  '4hours',
#  '4in1versatile',
#  '4inch',
#  '4k',
#  '4loose',
#  '4mb',
#  '4months',
#  '4player',
#  '4pm',
#  '4s',
#  '4th',
#  '4u',
#  '4us',
#  '4v',
#  '4x4',
#  '50',
#  '500',
#  '5000',
#  '500gb',
#  '500hz',
#  '501',
#  '505',
#  '50g',
#  '50mm',
#  '50th',
#  '51',
#  '510',
#  '512',
#  '513',
#  '52',
#  '5200',
#  '529',
#  '53',
#  '54',
#  '55',
#  '5500',
#  '56',
#  '58',
#  '59',
#  '59blocks',
#  '59pm',
#  '5c',
#  '5cm',
#  '5ds',
#  '5ft',
#  '5games',
#  '5k',
#  '5lbs',
#  '5m',
#  '5mm',
#  '5pm',
#  '5s',
#  '5th',
#  '5v',
#  '60',
#  '600',
#  '60hz',
#  '60p',
#  '61',
#  '626',
#  '63mm',
#  '64',
#  '64s',
#  '65',
#  '66',
#  '67',
#  '67f',
#  '69',
#  '6_',
#  '6for',
#  '6games',
#  '6ghz',
#  '6s',
#  '6splus',
#  '6v',
#  '6x',
#  '70',
#  '700',
#  '7000',
#  '700mah',
#  '70s',
#  '71',
#  '71205',
#  '71228',
#  '71230',
#  '71231',
#  '71233',
#  '71235',
#  '71236',
#  '71237',
#  '71241',
#  '72',
#  '720',
#  '7200rpm',
#  '721',
#  '725',
#  '73',
#  '75',
#  '7528',
#  '7580',
#  '75in',
#  '76',
#  '772',
#  '7780',
#  '78',
#  '7800',
#  '79',
#  '7th',
#  '7v',
#  '80',
#  '800',
#  '8000',
#  '80116',
#  '80mah',
#  '80s',
#  '8150',
#  '8200dpi',
#  '822152',
#  '83998888',
#  '844',
#  '85',
#  '86',
#  '874',
#  '88',
#  '89',
#  '8gb',
#  '8gig',
#  '8mb',
#  '8mg',
#  '8x',
#  '90',
#  '900',
#  '900ma',
#  '90s',
#  '90smomma',
#  '91',
#  '92',
#  '921',
#  '925',
#  '927',
#  '93',
#  '932',
#  '94',
#  '95',
#  '951',
#  '95g',
#  '96',
#  '960',
#  '97',
#  '9780744015201',
#  '98',
#  '980',
#  '9862',
#  '99',
#  '990fx',
#  '995',
#  '999',
#  '99909',
#  '999999999',
#  '99at',
#  '9f',
#  '9ft',
#  '9x10',
#  '9x3',
#  '_____________________',
#  '_______________________________',
#  '_______________________________________________________',
#  '_no',
#  '_pierre97',
#  'a2',
#  'a40',
#  'a40s',
#  'a50s',
#  'aa',
#  'aaa',
#  'aaahh',
#  'aand',
#  'aasales11',
#  'abandoned',
#  'abba',
#  'abc',
#  'abd',
#  'abercrombie',
#  'abh',
#  'abilities',
#  'ability',
#  'able',
#  'about',
#  'above',
#  'abrasions',
#  'abroad',
#  'abs',
#  'absolute',
#  'absolutely',
#  'absolution',
#  'absoolute',
#  'abxy',
#  'aby',
#  'abyss',
#  'ac',
#  'academic',
#  'academy',
#  'acceleration',
#  'accelerator',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'accesories',
#  'access',
#  'accessibility',
#  'accessible',
#  'accessories',
#  'accessory',
#  'accident',
#  'accidentally',
#  'accidently',
#  'acclaimed',
#  'accommodate',
#  'accompanying',
#  'according',
#  'accordingly',
#  'account',
#  'accounts',
#  'accuracy',
#  'accuse',
#  'ace',
#  'acer',
#  'achieve',
#  'achievements',
#  'acid',
#  'acknowledge',
#  'acldc',
#  'acme',
#  'acne',
#  'acnl',
#  'acoustic',
#  'acro',
#  'across',
#  'acrylic',
#  'act',
#  'action',
#  'activate',
#  'activated',
#  'activates',
#  'activation',
#  'activator',
#  'active',
#  'activision',
#  'activities',
#  'activity',
#  'actors',
#  'actraiser',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adamantium',
#  'adapter',
#  'adapters',
#  'adaptive',
#  'adaptor',
#  'add',
#  'addams',
#  'added',
#  'adderall',
#  'addicting',
#  'addictive',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'address',
#  'addressed',
#  'addresses',
#  'adds',
#  'adhd',
#  'adhesive',
#  'adidas',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'administration',
#  'admiral',
#  'admit',
#  'adopt',
#  'adorable',
#  'adrenaline',
#  'ads',
#  'adult',
#  'adults',
#  'advanc',
#  'advance',
#  'advanced',
#  'advances',
#  'advantage',
#  'advent',
#  'adventure',
#  'adventures',
#  'adventurous',
#  'advertise',
#  'advertisement',
#  'advertisements',
#  'advertising',
#  'aero',
#  'aerocraft',
#  'aeropostale',
#  'aerosmith',
#  'aeroz',
#  'af',
#  'affair',
#  'affairs',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'affordable',
#  'affords',
#  'afloat',
#  'afraid',
#  'africa',
#  'african',
#  'after',
#  'aftermarket',
#  'aftermath',
#  'afternoon',
#  'again',
#  'against',
#  'agarest',
#  'agassi',
#  'agatha',
#  'age',
#  'age2',
#  'aged',
#  'ageless',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggravation',
#  'aggressive',
#  'ago',
#  'agony',
#  'agree',
#  'agreed',
#  'agreement',
#  'ags',
#  'ags101',
#  'ah',
#  'ahead',
#  'ahhhh',
#  'ahri',
#  'ahsoka',
#  'ai',
#  'aided',
#  'aikman',
#  'aim',
#  'aims',
#  'ain',
#  'aint',
#  'air',
#  'airbender',
#  'airborne',
#  'aircraft',
#  'airrider',
#  'aj',
#  'aka',
#  'akatsuki',
#  'al',
#  'aladdin',
#  'aladin',
#  'alan',
#  'alarm',
#  'alaska',
#  'alaskan',
#  'albert',
#  'albertsons',
#  'album',
#  'alcatraz',
#  'alchemist',
#  'alcohol',
#  'aldous',
#  'ale',
#  'alekhine',
#  'alert',
#  'aleste',
#  'alex',
#  'alexa',
#  'alexander1798',
#  'algebra',
#  'alias',
#  'alibur',
#  'alice',
#  'alien',
#  'aliens',
#  'alienware',
#  'alignment',
#  'alike',
#  'alisonveld',
#  'alive',
#  'alivin',
#  'alkaline',
#  'all',
#  'alley',
#  'allhave',
#  'alliance',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'allready',
#  'allstar',
#  'allstars',
#  'alluring',
#  'alma',
#  'almia',
#  'almost',
#  'aloha',
#  'alola',
#  'alone',
#  'along',
#  'alongside',
#  'alot',
#  'alown',
#  'alpha',
#  'alphabet',
#  'already',
#  'alright',
#  'alround',
#  'also',
#  'alter',
#  'altered',
#  'alternate',
#  'alternative',
#  'although',
#  'altitude',
#  'altogether',
#  'aluminum',
#  'alundra',
#  'alvin',
#  'always',
#  'alyssa',
#  'am',
#  'amagon',
#  'amanda',
#  'amazed',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'ambidextrous',
#  'ambitions',
#  'ambitious',
#  'america',
#  'american',
#  'amf',
#  'amidst',
#  'amie',
#  'amigo',
#  'amiibo',
#  'amiibos',
#  'amino',
#  'ammo',
#  'amnesia',
#  'among',
#  'amongst',
#  'amorines',
#  'amount',
#  'amp',
#  'amped',
#  'amuck',
#  'amulet',
#  'amusement',
#  'amweber',
#  'an',
#  'ana',
#  'anacondas',
#  'anakin',
#  'analig',
#  'analog',
#  'anarchy',
#  'ancient',
#  'and',
#  'andninja',
#  'andreas',
#  'andres',
#  'andretti',
#  'andrew',
#  'android',
#  'androids',
#  'andromeda',
#  'ands',
#  'andy',
#  'anew',
#  'angel',
#  'angeles',
#  'angels',
#  'angelz',
#  'anger',
#  'angle',
#  'angles',
#  'angry',
#  'angrybirds',
#  'animal',
#  'animalcrossing',
#  'animals',
#  'animaniacs',
#  'animate',
#  'animated',
#  'animation',
#  'animations',
#  'anime',
#  'anki',
#  'anna',
#  'annihilation',
#  'anniversary',
#  'anniversay',
#  'announced',
#  'announcement',
#  'anonymous',
#  'another',
#  'answer',
#  'answered',
#  'answers',
#  'ant',
#  'ante',
#  'anthology',
#  'anthony',
#  'anthropologie',
#  'anti',
#  'anticipation',
#  'antique',
#  'antivirus',
#  'anton',
#  'anxiety',
#  'any',
#  'anya',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'aot',
#  'apart',
#  'apartment',
#  'ape',
#  'apo',
#  'apocalypse',
#  'apocalyptic',
#  'apocalypto',
#  'apollo',
#  'apologize',
#  'app',
#  'apparel',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appears',
#  'apple',
#  'applicable',
#  'application',
#  'applied',
#  'apply',
#  'appreciate',
#  'apprentice',
#  'approach',
#  'appropriate',
#  'approx',
#  'approximate',
#  'apps',
#  'apptivity',
#  'april',
#  'aqua',
#  'aquarium',
#  'aquila',
#  'ar',
#  'arabia',
#  'aradce',
#  'aragorn',
#  'arcade',
#  'arcadegames',
#  'arcades',
#  'arcadia',
#  'arcana',
#  'arceus',
#  'archam',
#  'archer',
#  'archers',
#  'archery',
#  'archives',
#  'archway',
#  'are',
#  'area',
#  'areas',
#  'aren',
#  'arena',
#  'arenas',
#  'arent',
#  'aria',
#  'ariana',
#  'ariel',
#  'ariels',
#  'arise',
#  'arisen',
#  'aristocracy',
#  'ark',
#  'arkham',
#  'arm',
#  'armaga',
#  'armageddon',
#  'armbrust',
#  'armed',
#  'armor',
#  'armored',
#  'armour',
#  'arms',
#  'army',
#  'arno',
#  'arnold',
#  'around',
#  'arrange',
#  'array',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arrow',
#  'arsenal',
#  'arsenals',
#  'art',
#  'artbook',
#  'artist',
#  'arts',
#  'artwork',
#  'as',
#  'asap',
#  'asault',
#  'ascension',
#  'asg',
#  ...]
